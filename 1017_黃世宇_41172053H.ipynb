# %% [markdown]
# 學習分析工具實務應用113-1 10/17
#
# Practical operatoin
#
# Review last work learning
#
# Viewing data (review last week learning)
#
# Export your data to your computer
#
# 了解資料型態 (review last week learning)
#
# Export data in excel pattern
#
# data sort (review last week learning)
#
# Getitem (review last week learning)
#
# 重複資料
#
# 次數分配表
#
# 處理 (review last week learning)
#
# Export data to Google sheet
#
# concat()
#
# join
#
# concat 2
#
# Merge

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('A_stat_data_112.csv')

# %%
df2 = df.copy()
df2.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
# 3          非連續                    112            112-2
# 4        連續＋圖表                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3  Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4  Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                     0                             NaN
# 1                 NaN                     0                             NaN
# 2                 NaN                     0                             NaN
# 3                 NaN                     0                             NaN
# 4                 NaN                     0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    first_correct_rate              user_id    mission_id
# 0                 NaN -8373966078912715601  8.154604e+18
# 1                 NaN  3516683932418412104  3.762301e+18
# 2                 NaN   -65799051578279613  4.652808e+18
# 3                 NaN -6293485111595748020  2.406214e+17
# 4                 NaN  4998280410504838977 -3.340858e+18
#
# [5 rows x 22 columns]

# %%
df.head()
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %%
df.tail(3)
# Out:
#       grade                mission_name mission_difficulty mission_field  \
# 9872      6  04/08 颱風小知識【環境教育－自然生態】（初階）                  中          生活知識
# 9873      6  04/08 火燒的天空【環境教育－自然生態】（初階）                  中          自然科學
# 9874      6  04/08 颱風小知識【環境教育－自然生態】（初階）                  中          生活知識
#
#      mission_type  mission_semester_year mission_semester  \
# 9872          非連續                    112            112-2
# 9873          非連續                    112            112-2
# 9874          非連續                    112            112-2
#
#              mission_datetime_utc8 mission_status  is_completed  ...  \
# 9872  Mon Apr 08 08:00:00 UTC 2024          已派發任務             0  ...
# 9873  Mon Apr 08 08:00:00 UTC 2024          已派發任務             0  ...
# 9874  Mon Apr 08 08:00:00 UTC 2024          已派發任務             0  ...
#
#      answer_duration_sec  mission_answer_count  \
# 9872                 NaN                     0
# 9873                 NaN                     0
# 9874                 NaN                     0
#
#       content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 9872                             NaN                                   NaN
# 9873                             NaN                                   NaN
# 9874                             NaN                                   NaN
#
#       explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 9872                                 NaN                                NaN
# 9873                                 NaN                                NaN
# 9874                                 NaN                                NaN
#
#       form_indicator_correct_rate  first_correct_rate              user_id  \
# 9872                          NaN                 NaN -7027693576974593760
# 9873                          NaN                 NaN -1239111061752899126
# 9874                          NaN                 NaN              4707905
#
#         mission_id
# 9872 -1.266328e+18
# 9873  8.266608e+18
# 9874           NaN
#
# [3 rows x 22 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9875, step=1)

# %%
df.columns
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %%
a = df2.columns
a_series = a.to_series()
print(a_series)
a_series.to_csv('work1.csv',index=False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# answer_duration_sec                                      answer_duration_sec
# mission_answer_count                                    mission_answer_count
# content_indicator_correct_rate                content_indicator_correct_rate
# comprehensive_indicator_correct_rate    comprehensive_indicator_correct_rate
# explanation_indicator_correct_rate        explanation_indicator_correct_rate
# extraction_indicator_correct_rate          extraction_indicator_correct_rate
# form_indicator_correct_rate                      form_indicator_correct_rate
# first_correct_rate                                        first_correct_rate
# user_id                                                              user_id
# mission_id                                                        mission_id
# dtype: object

# %%
df.describe()
# Out:
#              grade  mission_semester_year  is_completed  correct_rate  \
# count  9875.000000                 9875.0   9875.000000   1830.000000
# mean      5.148962                  112.0      0.185316      0.373552
# std       1.002522                    0.0      0.388574      0.307396
# min       4.000000                  112.0      0.000000      0.000000
# 25%       4.000000                  112.0      0.000000      0.200000
# 50%       5.000000                  112.0      0.000000      0.400000
# 75%       6.000000                  112.0      0.000000      0.600000
# max       9.000000                  112.0      1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count          1828.000000           9875.000000
# mean            125.157549              0.563646
# std             382.663984              1.613655
# min               1.000000              0.000000
# 25%               8.000000              0.000000
# 50%              21.000000              0.000000
# 75%             124.000000              0.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                      376.000000                           1809.000000
# mean                         0.356383                              0.378364
# std                          0.471154                              0.391426
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.666667
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                         1602.000000                        1661.000000
# mean                             0.340824                           0.400843
# std                              0.434034                           0.448480
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.000000
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                   323.000000         1910.000000  9.875000e+03
# mean                      0.377709            0.436824 -4.167863e+17
# std                       0.480746            0.311464  5.239627e+18
# min                       0.000000            0.000000 -9.202482e+18
# 25%                       0.000000            0.200000 -5.002785e+18
# 50%                       0.000000            0.400000 -4.107753e+17
# 75%                       1.000000            0.600000  3.799780e+18
# max                       1.000000            1.000000  9.188531e+18
#
#          mission_id
# count  9.874000e+03
# mean   1.236343e+15
# std    5.396921e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.265075e+17
# 75%    4.447409e+18
# max    9.217426e+18

# %%
b = df2.describe()
print(b)
b.to_excel('work2.xlsx')
# Out:
#              grade  mission_semester_year  is_completed  correct_rate  \
# count  9875.000000                 9875.0   9875.000000   1830.000000
# mean      5.148962                  112.0      0.185316      0.373552
# std       1.002522                    0.0      0.388574      0.307396
# min       4.000000                  112.0      0.000000      0.000000
# 25%       4.000000                  112.0      0.000000      0.200000
# 50%       5.000000                  112.0      0.000000      0.400000
# 75%       6.000000                  112.0      0.000000      0.600000
# max       9.000000                  112.0      1.000000      1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count          1828.000000           9875.000000
# mean            125.157549              0.563646
# std             382.663984              1.613655
# min               1.000000              0.000000
# 25%               8.000000              0.000000
# 50%              21.000000              0.000000
# 75%             124.000000              0.000000
# max            3600.000000             74.000000
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                      376.000000                           1809.000000
# mean                         0.356383                              0.378364
# std                          0.471154                              0.391426
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              0.666667
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                         1602.000000                        1661.000000
# mean                             0.340824                           0.400843
# std                              0.434034                           0.448480
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.000000
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                   323.000000         1910.000000  9.875000e+03
# mean                      0.377709            0.436824 -4.167863e+17
# std                       0.480746            0.311464  5.239627e+18
# min                       0.000000            0.000000 -9.202482e+18
# 25%                       0.000000            0.200000 -5.002785e+18
# 50%                       0.000000            0.400000 -4.107753e+17
# 75%                       1.000000            0.600000  3.799780e+18
# max                       1.000000            1.000000  9.188531e+18
#
#          mission_id
# count  9.874000e+03
# mean   1.236343e+15
# std    5.396921e+18
# min   -9.144214e+18
# 25%   -4.632199e+18
# 50%   -1.265075e+17
# 75%    4.447409e+18
# max    9.217426e+18

# %%
c = df.sort_index(axis=1, ascending=False)
c.to_excel('work3.xlsx')

# %%
df["mission_name"]
d = df[0:3]
d.to_excel('work4.xlsx')

# %%
e = 'grade'
df2.duplicated(subset=[e]).sum()
# Out:
# 9869

# %%
duplication = df2[df2.duplicated(a)]
duplication[a]
# Out:
# Empty DataFrame
# Columns: [grade, mission_name, mission_difficulty, mission_field, mission_type, mission_semester_year, mission_semester, mission_datetime_utc8, mission_status, is_completed, completed_at_utc8, correct_rate, answer_duration_sec, mission_answer_count, content_indicator_correct_rate, comprehensive_indicator_correct_rate, explanation_indicator_correct_rate, extraction_indicator_correct_rate, form_indicator_correct_rate, first_correct_rate, user_id, mission_id]
# Index: []
#
# [0 rows x 22 columns]

# %%
a = 'user_id'
df3 = df2.drop_duplicates(a)
df3
# Out:
#       grade                      mission_name mission_difficulty  \
# 0         5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1         5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2         6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3         5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4         6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...     ...                               ...                ...
# 8807      5      02/19 校外教學學習單【生命教育－校園生活】（初階）                  易
# 8838      6              2月特別任務－【SDGs 議題】（初階）                NaN
# 9194      4        03/07 家長同意書【資訊教育－圖表理解】（初階）                  中
# 9747      5      04/01 九九峰的新住民【多元文化－寶島生態】（初階）                  中
# 9874      6        04/08 颱風小知識【環境教育－自然生態】（初階）                  中
#
#      mission_field mission_type  mission_semester_year mission_semester  \
# 0               文學           連續                    112            112-2
# 1               文學           連續                    112            112-2
# 2               人物           連續                    112            112-2
# 3             生活知識          非連續                    112            112-2
# 4             自然科學        連續＋圖表                    112            112-2
# ...            ...          ...                    ...              ...
# 8807          生活知識          非連續                    112            112-2
# 8838           NaN          NaN                    112            112-2
# 9194          說明文件          非連續                    112            112-2
# 9747          自然科學           連續                    112            112-2
# 9874          生活知識          非連續                    112            112-2
#
#              mission_datetime_utc8 mission_status  is_completed  ...  \
# 0     Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1     Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2     Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3     Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4     Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                            ...            ...           ...  ...
# 8807  Mon Feb 19 08:00:00 UTC 2024          已派發任務             0  ...
# 8838  Thu Feb 22 08:00:00 UTC 2024          已派發任務             0  ...
# 9194  Thu Mar 07 08:00:00 UTC 2024          已派發任務             0  ...
# 9747  Mon Apr 01 08:00:00 UTC 2024          已派發任務             0  ...
# 9874  Mon Apr 08 08:00:00 UTC 2024          已派發任務             0  ...
#
#      answer_duration_sec  mission_answer_count  \
# 0                    NaN                     0
# 1                    NaN                     0
# 2                    NaN                     0
# 3                    NaN                     0
# 4                    NaN                     0
# ...                  ...                   ...
# 8807                 NaN                     0
# 8838                 NaN                     0
# 9194                 NaN                     0
# 9747                 NaN                     0
# 9874                 NaN                     0
#
#       content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ...                              ...                                   ...
# 8807                             NaN                                   NaN
# 8838                             NaN                                   NaN
# 9194                             NaN                                   NaN
# 9747                             NaN                                   NaN
# 9874                             NaN                                   NaN
#
#       explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 8807                                 NaN                                NaN
# 8838                                 NaN                                NaN
# 9194                                 NaN                                NaN
# 9747                                 NaN                                NaN
# 9874                                 NaN                                NaN
#
#       form_indicator_correct_rate  first_correct_rate              user_id  \
# 0                             NaN                 NaN -8373966078912715601
# 1                             NaN                 NaN  3516683932418412104
# 2                             NaN                 NaN   -65799051578279613
# 3                             NaN                 NaN -6293485111595748020
# 4                             NaN                 NaN  4998280410504838977
# ...                           ...                 ...                  ...
# 8807                          NaN                 NaN  5106542192022058529
# 8838                          NaN                 NaN -6581654370170749279
# 9194                          NaN                 NaN  1908519713361091863
# 9747                          NaN                 NaN  6028184551891289140
# 9874                          NaN                 NaN              4707905
#
#         mission_id
# 0     8.154604e+18
# 1     3.762301e+18
# 2     4.652808e+18
# 3     2.406214e+17
# 4    -3.340858e+18
# ...            ...
# 8807  2.643189e+18
# 8838 -8.878683e+18
# 9194  7.788849e+18
# 9747  2.961782e+18
# 9874           NaN
#
# [980 rows x 22 columns]

# %%
p = 'one two one two one two'.split()
p1 = 'a1 a2 a3 a4 a5 a6'.split()
df = pd.DataFrame(
    {
        "A":p,
        "B":p1,
        "C":np.random.randn(6),
        "D":np.random.randn(6),
    }
)

df
# Out:
#      A   B         C         D
# 0  one  a1  0.575786 -0.871145
# 1  two  a2 -1.890838 -0.443811
# 2  one  a3  0.500185 -0.373580
# 3  two  a4 -0.433517 -1.851920
# 4  one  a5  1.153373  1.667744
# 5  two  a6 -0.583911 -1.404656

# %%
p = 'one two one two one two'.split()
p1 = 'a1 a2 a3 a4 a5 a6'.split()
df2 = pd.DataFrame(
    {
        "A":p,
        "B":p1,
        "C":np.random.randn(6),
        "D":np.random.randn(6),
    }
)

df2
df2.groupby(["A","B"]).sum()
# Out:
#                C         D
# A   B
# one a1 -1.388255 -0.405918
#     a3 -2.607433 -2.219884
#     a5 -0.187965  1.161039
# two a2 -0.064681  0.199285
#     a4  0.896780  0.517771
#     a6 -2.046253  0.226896

# %%
p = 'one two one two one two'.split()
p1 = 'a1 a2 a3 a4 a5 a6'.split()
df2 = pd.DataFrame(
    {
        "A":p,
        "B":p1,
        "C":np.random.randn(6),
        "D":np.random.randn(6),
    }
)

df2
a = df2.columns
pp2 = []
for j in a:
 try:
  print(df2[j].groupby(df2[j]).count())
  pp2.append(df2[j].groupby(df2[j]).count())
 except:
  print("KeyError")
# Out:
# A
# one    3
# two    3
# Name: A, dtype: int64
# B
# a1    1
# a2    1
# a3    1
# a4    1
# a5    1
# a6    1
# Name: B, dtype: int64
# C
# -1.332586    1
# -0.949480    1
# -0.533860    1
# -0.234862    1
# -0.111866    1
#  1.104619    1
# Name: C, dtype: int64
# D
# -2.167822    1
# -0.946260    1
# -0.580634    1
#  0.764638    1
#  0.994965    1
#  1.376845    1
# Name: D, dtype: int64

# %%
p = 'one two one two one two'.split()
p1 = 'a1 a2 a3 a4 a5 a6'.split()
df2 = pd.DataFrame(
    {
        "A":p,
        "B":p1,
        "C":np.random.randn(6),
        "D":np.random.randn(6),
    }
)

df2
with open('次數table_3.txt', 'w', encoding = 'utf-8') as f:
  f.write(str(pp2))
  f.close

# %%
df2.dropna( )
# Out:
#      A   B         C         D
# 0  one  a1 -0.114516  0.222320
# 1  two  a2  0.439373 -1.179456
# 2  one  a3  1.096972  0.796169
# 3  two  a4  0.681544 -0.318119
# 4  one  a5  1.172430 -0.033631
# 5  two  a6 -0.295159  0.428689

# %%
df2.fillna(5)
# Out:
#      A   B         C         D
# 0  one  a1 -0.114516  0.222320
# 1  two  a2  0.439373 -1.179456
# 2  one  a3  1.096972  0.796169
# 3  two  a4  0.681544 -0.318119
# 4  one  a5  1.172430 -0.033631
# 5  two  a6 -0.295159  0.428689

# %%
df2.interpolate( )
# Out:
# <ipython-input-50-7d4e34ec92e6>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df2.interpolate( )
#      A   B         C         D
# 0  one  a1 -0.114516  0.222320
# 1  two  a2  0.439373 -1.179456
# 2  one  a3  1.096972  0.796169
# 3  two  a4  0.681544 -0.318119
# 4  one  a5  1.172430 -0.033631
# 5  two  a6 -0.295159  0.428689

# %%
df.head(10000).to_excel('output_partial_data.xlsx', index=False)
print("成功將部分數據保存到 Excel 文件")
# Out:
# 成功將部分數據保存到 Excel 文件

# %%
df3 = df.head(10000)
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds,_=default()

gc = gspread.authorize(creds)

import pandas as pd
gsheets = gc.open_by_url("https://drive.google.com/drive/folders/1Ay5hxfQ0k3ieECumcrxBfaSUY3DQ2kKF?usp=sharing")

from gspread_dataframe import set_with_dataframe
worksheet = gsheets.get_worksheet(0)
set_with_dataframe(worksheet,df3)
# Out:
# ---------------------------------------------------------------------------
# NoValidUrlKeyFound                        Traceback (most recent call last)
# <ipython-input-59-0a78f627e562> in <cell line: 12>()
#      10
#      11 import pandas as pd
# ---> 12 gsheets = gc.open_by_url("https://drive.google.com/drive/folders/1Ay5hxfQ0k3ieECumcrxBfaSUY3DQ2kKF?usp=sharing")
#      13
#      14 from gspread_dataframe import set_with_dataframe
#
# /usr/local/lib/python3.10/dist-packages/gspread/client.py in open_by_url(self, url)
#     165         >>> gc.open_by_url('https://docs.google.com/spreadsheet/ccc?key=0Bm...FE&hl')
#     166         """
# --> 167         return self.open_by_key(extract_id_from_url(url))
#     168
#     169     def openall(self, title: Optional[str] = None) -> List[Spreadsheet]:
#
# /usr/local/lib/python3.10/dist-packages/gspread/utils.py in extract_id_from_url(url)
#     559         return m1.group(1)
#     560
# --> 561     raise NoValidUrlKeyFound
#     562
#     563
#
# NoValidUrlKeyFound:

# %%
df1 = pd.DataFrame(
{
"A": ["A0", "A1", "A2", "A3"],"B": ["B0", "B1", "B2", "B3"], "C": ["C0", "C1", "C2", "C3"], "D": ["D0", "D1", "D2", "D3"],
},
index=[0, 1, 2, 3],
)
df2 = pd.DataFrame(
{
"A": ["A4", "A5", "A6", "A7"], "B": ["B4", "B5", "B6", "B7"], "C": ["C4", "C5", "C6", "C7"], "D": ["D4", "D5", "D6", "D7"],
},
index=[4, 5, 6, 7],
)
df3 = pd.DataFrame(
{
"A": ["A8", "A9", "A10", "A11"], "B": ["B8", "B9", "B10", "B11"], "C": ["C8", "C9", "C10", "C11"], "D": ["D8", "D9", "D10", "D11"],
},
index=[8, 9, 10, 11],)
frames = [df1, df2, df3]
result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame(
{
"B": ["B2", "B3", "B6", "B7"],
"D": ["D2", "D3", "D6", "D7"],
"F": ["F2", "F3", "F6", "F7"],
},
index=[2, 3, 6, 7],
)
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
left = pd.DataFrame({"key": ["A","B"], "lval": [1,2]})
print(left)
right = pd.DataFrame({"key": ["A","B"], "rval": [3,4]})
print(right)
pd.merge(right, left, on="key")
# Out:
#   key  lval
# 0   A     1
# 1   B     2
#   key  rval
# 0   A     3
# 1   B     4
#   key  rval  lval
# 0   A     3     1
# 1   B     4     2

# %%
gf= []
ww = df['grade']
for i in range(len(ww)):
 i += 1
 gf.append(i)
df4 = pd.DataFrame(gf)
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grade'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-257db2eb3fd3> in <cell line: 2>()
#       1 gf= []
# ----> 2 ww = df['grade']
#       3 for i in range(len(ww)):
#       4  i += 1
#       5  gf.append(i)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'grade'
